# %% [markdown]
# ### Importación de Tensorflow

# %%
# %tensorflow_version 2.x

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
#importar celdas recurrentes 
from tensorflow.compat.v1.nn import rnn_cell
import csv
# %matplotlib inline

# %% [markdown]
# ### Importación de datos

# %%
! git clone https://github.com/Duchanoy/BolsaDeValores.git
# Out:
# Cloning into 'BolsaDeValores'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
# !ls
# %cd BolsaDeValores
# !ls
# Out:
# BolsaDeValores	sample_data
# /content/BolsaDeValores
# hpq.us.txt  README.md

# %%
date=[]
High=[]
Low=[]
with open('hpq.us.txt', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    for i,row in enumerate(spamreader):
        if i == 0:
            print(row)
            print(len(row))
        else: 
            date.append(row[0])
            
            High.append(float(row[2]))
            Low.append(float(row[3]))
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt']
# 7

# %%
len(date)
# Out:
# 12075

# %% [markdown]
# ### verificando los datos de prueba

# %%
plt.figure(figsize = (18,9))
plt.plot(range(len(date)),(np.array(Low)+np.array(High))/2.0)
plt.xticks(range(0,len(date),500),date[0::500],rotation=45)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Mid Price',fontsize=18)
plt.show()

# %%
mid_prices = (np.array(Low)+np.array(High))/2.0

# %%
Train_data = mid_prices[:11000]
Test_data = mid_prices

# %%
def data_genertor(data, window , distance=0):
    x=[]
    y=[]
    for i in range(len(data)-window-distance):
        x.append(data[i:i+window])
        y.append(data[i+window+distance])
    return np.array(x),np.array(y)

# %%
train_x,train_y=data_genertor(Train_data, 10 , 0)

# %%
print(train_x.shape)
print(train_y.shape)
# Out:
# (10990, 10)
# (10990,)

# %%
test_x,test_y=data_genertor(Test_data, 10 , 0)

# %%
print(test_x.shape)
print(test_y.shape)
# Out:
# (12065, 10)
# (12065,)

# %% [markdown]
# ### Declarando la arquitectura
#
# Generando función

# %%
RNN=tf.keras.Sequential()
RNN.add(tf.keras.layers.LSTM(units=1,input_shape=(10,1),activation="relu"))
RNN.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 1)                 12
# =================================================================
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# _________________________________________________________________

# %%
RNN.compile(optimizer='adam', loss='mean_squared_error')

# %%
#  input shape must be [samples, time steps, features]
train_x = np.reshape(train_x, (train_x.shape[0], train_x.shape[1],1))
test_x = np.reshape(test_x, (test_x.shape[0], test_x.shape[1],1))

RNN.fit(train_x,train_y,
                epochs=100,
                batch_size=100,
                shuffle=False
                )
# Out:
# Epoch 1/100
# 110/110 [==============================] - 0s 4ms/step - loss: 73.5236
# Epoch 2/100
# 110/110 [==============================] - 0s 4ms/step - loss: 71.3515
# Epoch 3/100
# 110/110 [==============================] - 0s 4ms/step - loss: 62.8636
# Epoch 4/100
# 110/110 [==============================] - 0s 4ms/step - loss: 38.5983
# Epoch 5/100
# 110/110 [==============================] - 0s 4ms/step - loss: 15.6105
# Epoch 6/100
# 110/110 [==============================] - 0s 4ms/step - loss: 5.9994
# Epoch 7/100
# 110/110 [==============================] - 0s 4ms/step - loss: 2.5400
# Epoch 8/100
# 110/110 [==============================] - 0s 4ms/step - loss: 1.6273
# Epoch 9/100
# 110/110 [==============================] - 0s 4ms/step - loss: 1.3126
# Epoch 10/100
# 110/110 [==============================] - 1s 5ms/step - loss: 1.0899
# Epoch 11/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.8942
# Epoch 12/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.7342
# Epoch 13/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.6103
# Epoch 14/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.5158
# Epoch 15/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.4434
# Epoch 16/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.3874
# Epoch 17/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.3434
# Epoch 18/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.3083
# Epoch 19/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.2800
# Epoch 20/100
# 110/110 [==============================] - 0s 5ms/step - loss: 0.2568
# Epoch 21/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.2374
# Epoch 22/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.2210
# Epoch 23/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.2070
# Epoch 24/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.1949
# Epoch 25/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.1842
# Epoch 26/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.1749
# Epoch 27/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1667
# Epoch 28/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1594
# Epoch 29/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.1532
# Epoch 30/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1478
# Epoch 31/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1432
# Epoch 32/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1393
# Epoch 33/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1360
# Epoch 34/100
# 110/110 [==============================] - 0s 5ms/step - loss: 0.1332
# Epoch 35/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1306
# Epoch 36/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1283
# Epoch 37/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1261
# Epoch 38/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1240
# Epoch 39/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1220
# Epoch 40/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1201
# Epoch 41/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1183
# Epoch 42/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1166
# Epoch 43/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1150
# Epoch 44/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1134
# Epoch 45/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1119
# Epoch 46/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1105
# Epoch 47/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1091
# Epoch 48/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1078
# Epoch 49/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1065
# Epoch 50/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1052
# Epoch 51/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1040
# Epoch 52/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1029
# Epoch 53/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1018
# Epoch 54/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.1007
# Epoch 55/100
# 110/110 [==============================] - 0s 5ms/step - loss: 0.0996
# Epoch 56/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0986
# Epoch 57/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0976
# Epoch 58/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0966
# Epoch 59/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0956
# Epoch 60/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0946
# Epoch 61/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0937
# Epoch 62/100
# 110/110 [==============================] - 0s 5ms/step - loss: 0.0927
# Epoch 63/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0917
# Epoch 64/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0908
# Epoch 65/100
# 110/110 [==============================] - 0s 5ms/step - loss: 0.0898
# Epoch 66/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0888
# Epoch 67/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0878
# Epoch 68/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0869
# Epoch 69/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0859
# Epoch 70/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0849
# Epoch 71/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0839
# Epoch 72/100
# 110/110 [==============================] - 0s 5ms/step - loss: 0.0829
# Epoch 73/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0820
# Epoch 74/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0810
# Epoch 75/100
# 110/110 [==============================] - 0s 5ms/step - loss: 0.0800
# Epoch 76/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0791
# Epoch 77/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0781
# Epoch 78/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0772
# Epoch 79/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0762
# Epoch 80/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0753
# Epoch 81/100
# 110/110 [==============================] - 0s 5ms/step - loss: 0.0744
# Epoch 82/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0736
# Epoch 83/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0727
# Epoch 84/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0718
# Epoch 85/100
# 110/110 [==============================] - 0s 5ms/step - loss: 0.0710
# Epoch 86/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0702
# Epoch 87/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0694
# Epoch 88/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0687
# Epoch 89/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0679
# Epoch 90/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0672
# Epoch 91/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0665
# Epoch 92/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0658
# Epoch 93/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0650
# Epoch 94/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0643
# Epoch 95/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0635
# Epoch 96/100
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0627
# Epoch 97/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0619
# Epoch 98/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0610
# Epoch 99/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0600
# Epoch 100/100
# 110/110 [==============================] - 0s 4ms/step - loss: 0.0591

# %% [markdown]
# ## función de prueba

# %%
Salidas=RNN.predict(test_x,verbose=True)
# Out:
# 378/378 [==============================] - 1s 2ms/step

# %%
plt.figure(figsize = (18,9))
plt.plot(range(len(date[10:])),mid_prices[10:])
plt.plot(range(len(date[10:])),Salidas,color="green")
plt.xticks(range(0,len(date),500),date[0::500],rotation=45)
plt.xlabel('Date',fontsize=18)
plt.ylabel('Mid Price',fontsize=18)
plt.show()
