# %% [markdown]
# ### Importación de Tensorflow

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### instalar NLTK
# - pip3 install nltk

# %% [markdown]
# ### Importar datos del data set

# %%
! git clone https://github.com/Duchanoy/SentimentDataSet.git
# Out:
# Cloning into 'SentimentDataSet'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 8 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (8/8), done.

# %%
# !ls
# %cd SentimentDataSet
# !ls
# Out:
# sample_data  SentimentDataSet
# /content/SentimentDataSet
# LICENSE  neg.txt  pos.txt  README.md

# %% [markdown]
# # Pre-procesando los datos

# %%
import nltk
from nltk.tokenize import word_tokenize
import numpy as np
import random
import pickle
from collections import Counter
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
def create_lexicon(pos,neg,hm_lines,Batches):

    lexicon = []
    with open(pos,'r') as f:
        contents = f.readlines()
        for l in contents[:hm_lines*Batches]:
            all_words = word_tokenize(l)
            lexicon += list(all_words)

    with open(neg,'r') as f:
        contents = f.readlines()
        for l in contents[:hm_lines*Batches]:
            all_words = word_tokenize(l)
            lexicon += list(all_words)
    lexicon = [lemmatizer.lemmatize(i) for i in lexicon]
    w_counts = Counter(lexicon)
    print(w_counts)
    l2 = []
    for w in w_counts:
        #print(w_counts[w])
        if 1000 > w_counts[w] > 50:
            l2.append(w)
    print(len(l2))
    return l2

# %%
def sample_handling(sample,lexicon,classification,hm_lines,Batch_number):

    featureset = []

    with open(sample,'r') as f:
        contents = f.readlines()
        for l in contents[hm_lines*(Batch_number):hm_lines*(Batch_number+1)]:
            current_words = word_tokenize(l.lower())
            current_words = [lemmatizer.lemmatize(i) for i in current_words]
            features = np.zeros(len(lexicon))
            for word in current_words:
                if word.lower() in lexicon:
                    index_value = lexicon.index(word.lower())
                    features[index_value] += 1

            features = list(features)
            featureset.append([features,classification])

    return featureset

# %%
def create_feature_sets_and_labels(pos,neg,hm_lines,Nbatch,test_size = 0.1):
    lexicon = create_lexicon(pos,neg,hm_lines,Nbatch)
    test_x=[]
    test_y=[]
    for BN in range(Nbatch):
        features = []
        features += sample_handling('pos.txt',lexicon,[1,0],hm_lines,BN)
        features += sample_handling('neg.txt',lexicon,[0,1],hm_lines,BN)
        random.shuffle(features)
        features = np.array(features)

        testing_size = int(test_size*len(features))

        train_x = list(features[:,0][:-testing_size])
        train_y = list(features[:,1][:-testing_size])
        test_x += list(features[:,0][-testing_size:])
        test_y += list(features[:,1][-testing_size:])
        
        with open('sentiment_set'+str(BN)+'.pickle','wb') as f:
            pickle.dump([np.array(train_x).astype("float32"),np.array(train_y).astype("float32")],f)
        
    with open('sentiment_set'+"test"+'.pickle','wb') as f:
        pickle.dump([np.array(test_x).astype("float32"),np.array(test_y).astype("float32")],f)

# %%
hm_lines = 2500
Batches=2
create_feature_sets_and_labels('pos.txt','neg.txt',hm_lines=hm_lines,Nbatch=Batches)
# Out:
# Counter({'.': 13134, 'the': 9460, ',': 9400, 'a': 8526, 'and': 5821, 'of': 5706, 'it': 4449, 'to': 3982, 'is': 3328, "'s": 3324, 'that': 2490, 'in': 2457, 'film': 1665, 'but': 1540, 'with': 1471, 'movie': 1459, 'this': 1367, 'for': 1360, 'an': 1235, 'you': 1096, 'be': 880, "n't": 875, 'on': 838, 'not': 781, 'by': 754, 'one': 705, 'are': 695, 'more': 687, 'about': 687, 'ha': 679, 'like': 668, 'at': 655, 'from': 637, 'than': 625, '--': 619, '``': 607, 'have': 602, 'his': 602, 'all': 597, 'i': 540, 'so': 523, "'": 506, 'if': 505, 'make': 498, 'or': 496, 'story': 495, 'character': 450, 'what': 439, 'who': 435, 'there': 431, 'too': 429, 'time': 422, 'just': 418, 'into': 396, 'doe': 385, 'most': 376, 'out': 374, 'much': 368, 'no': 365, 'comedy': 362, 'good': 360, 'even': 356, 'will': 352, 'up': 352, 'can': 338, 'some': 313, 'way': 312, 'performance': 311, 'work': 305, 'he': 295, 'only': 290, 'little': 286, 'their': 277, 'do': 273, 'funny': 268, 'life': 264, 'director': 259, '[': 258, ']': 258, 'get': 255, 'been': 254, 'feel': 253, 'they': 252, 'enough': 251, 'very': 247, 'never': 244, 'when': 244, 'your': 243, 'we': 238, 'u': 237, 'may': 235, 'would': 229, 'which': 225, 'thing': 223, 'love': 220, 'bad': 220, 'best': 218, 'look': 217, 'any': 213, ')': 211, 'wa': 211, 'could': 211, '(': 209, '?': 208, 'while': 207, 'take': 206, 'come': 202, 'her': 202, ':': 201, 'well': 200, 'new': 190, 'through': 190, 'audience': 187, 'really': 186, 'year': 186, 'made': 184, 'how': 182, 'something': 181, 'should': 179, 'plot': 179, 'see': 178, 'own': 177, 'them': 176, 'those': 174, 'drama': 174, 'every': 173, 'many': 171, 'still': 170, 'go': 168, 'two': 167, 'people': 166, 'better': 161, "'re": 161, 'being': 160, 'nothing': 160, 'give': 159, 'action': 158, 'without': 158, 'fun': 157, 'off': 157, 'other': 155, 'might': 154, 'long': 154, 'end': 153, 'great': 152, 'both': 152, 'picture': 151, 'big': 150, 'though': 147, 'here': 147, 'cast': 146, 'actor': 144, 'script': 143, 'another': 142, 'moment': 141, 'between': 140, 'sense': 139, 'kind': 139, 'minute': 137, 'world': 137, 'humor': 137, 'first': 136, 'also': 135, 'over': 135, 'lot': 135, 'ever': 134, 'tale': 134, 'such': 134, 'le': 133, 'far': 131, 'scene': 130, 'few': 129, 'because': 127, 'thriller': 127, 'seems': 127, ';': 126, 'documentary': 124, 'real': 124, 'often': 123, 'interesting': 121, 'find': 120, 'heart': 119, 'down': 119, 'yet': 119, 'screen': 119, 'ca': 119, 'quite': 118, 'show': 117, 'lack': 116, 'man': 115, 'idea': 114, "'ll": 114, 'family': 114, 'want': 113, 'my': 113, 'american': 113, 'these': 113, 'play': 112, 'almost': 112, '!': 112, 'keep': 112, 'hollywood': 112, "'ve": 112, 'full': 110, 'woman': 110, 'filmmaker': 109, 'know': 109, 'were': 109, 'itself': 108, 'watching': 108, 'de': 107, 'hard': 107, 'seen': 107, 'rather': 106, 'ultimately': 105, 'point': 105, 'kid': 105, 'entertaining': 105, 'romantic': 104, 'had': 104, 'piece': 104, 'right': 104, 'part': 103, 'laugh': 103, 'despite': 103, 'me': 103, 'after': 103, 'offer': 102, 'original': 101, 'need': 100, 'acting': 100, 'where': 100, 'worth': 99, 'then': 99, 'human': 99, 'same': 99, 'old': 98, 'before': 98, 'think': 97, 'turn': 95, 'back': 95, 'star': 94, 'material': 93, 'watch': 92, 'fan': 92, 'our': 91, 'subject': 91, 'once': 91, 'compelling': 90, 'young': 90, 'say': 90, 'bit': 90, 'music': 89, 'day': 89, 'hour': 88, 'anyone': 86, 'cinema': 85, 'place': 83, 'dialogue': 83, 'seem': 83, 'she': 83, 'going': 82, 'experience': 82, 'flick': 82, 'least': 82, 'did': 82, 'viewer': 80, 'last': 80, 'emotional': 80, 'cinematic': 79, 'set': 79, 'again': 79, 'sometimes': 78, 'entertainment': 78, 'style': 78, 'put': 78, 'anything': 78, 'whole': 77, 'making': 76, 'together': 76, 'charm': 76, 'child': 76, 'special': 76, 'effect': 76, 'care': 75, 'power': 75, 'away': 74, 'since': 74, 'matter': 74, 'pretty': 74, 'fascinating': 73, '-': 73, 'dull': 73, 'genre': 72, 'why': 71, 'true': 71, 'moving': 71, 'sweet': 71, 'video': 71, 'problem': 71, 'dire ...
# 389

# %%
# !ls
# Out:
# LICENSE  pos.txt    sentiment_set0.pickle  sentiment_settest.pickle
# neg.txt  README.md  sentiment_set1.pickle

# %% [markdown]
# ### Importación de datos

# %%
with open('sentiment_set0.pickle','rb') as f:
    train_x,train_y=pickle.load(f)
with open('sentiment_settest.pickle','rb') as f:
    test_x,test_y=pickle.load(f)

# %%
print(train_x.shape)
print(test_x.shape)
# Out:
# (4500, 389)
# (1000, 389)

# %% [markdown]
# ### Declarando la arquitectura
#
# Generando función

# %%
class DNN_model(object):
  def __init__(self,
               LnInput,
               n_nodes_hl1=500,
               n_nodes_hl2=500,
               n_nodes_hl3=500,
               n_classes=10):
    self.h1LW = tf.Variable(np.random.rand(LnInput, n_nodes_hl1),name="hl1weigths",dtype="float32")
    self.h1LB = tf.Variable(np.random.rand(n_nodes_hl1),name="hl1bias",dtype="float32")
    self.h2LW = tf.Variable(np.random.rand(n_nodes_hl1, n_nodes_hl2),name="hl2weigths",dtype="float32")
    self.h2LB = tf.Variable(np.random.rand(n_nodes_hl2),name="hl2bias",dtype="float32")
    self.h3LW = tf.Variable(np.random.rand(n_nodes_hl2, n_nodes_hl3),name="hl3weigths",dtype="float32")
    self.h3LB = tf.Variable(np.random.rand(n_nodes_hl3),name="hl3bias",dtype="float32")
    self.outW = tf.Variable(np.random.rand(n_nodes_hl3, n_classes),name="outweigths",dtype="float32")
    self.outB = tf.Variable(np.random.rand(n_classes),name="outbias",dtype="float32")
    self.trainable_variables =[self.h1LW,self.h1LB,self.h2LW,self.h2LB,self.h3LW,self.h3LB,self.outW,self.outB]          
  def __call__(self,x): 
      # Declarando la arquitectura

      l1 = tf.add(tf.matmul(x,self.h1LW), self.h1LB)
      l1 = tf.nn.relu(l1)

      l2 = tf.add(tf.matmul(l1,self.h2LW), self.h2LB)
      l2 = tf.nn.relu(l2)

      l3 = tf.add(tf.matmul(l2,self.h3LW), self.h3LB)
      l3 = tf.nn.relu(l3)

      output = tf.matmul(l3,self.outW) + self.outB
      return output

# %%
 Sentiment_model = DNN_model(len(train_x[0]), n_classes=2)

# %% [markdown]
# Seleccionar un optimizador

# %%
optimizador = tf.compat.v1.train.AdamOptimizer(learning_rate=0.001)

# %% [markdown]
# ### Definir las metricas a usar

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.CategoricalAccuracy(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name='test_loss')
test_accuracy = tf.keras.metrics.CategoricalAccuracy(name='test_accuracy')

# %% [markdown]
# ### Calculo de gradientes y ajuste

# %%
@tf.function
def train_step(model,tdata, labels):
  with tf.GradientTape() as tape:
    predictions = model(tdata)
    #calculo de una funcion de error 
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels, predictions))
   
  gradients = tape.gradient(loss, model.trainable_variables)
  capped_grads_and_vars = [(grad,model.trainable_variables[index]) for index, grad in enumerate(gradients)]
  optimizador.apply_gradients(capped_grads_and_vars)
  train_loss(loss)
  train_accuracy(labels, predictions)

# %%
@tf.function
def test_step(model,tdata, labels):
  predictions = model(tdata)
  t_loss =  tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels, predictions))

  test_loss(t_loss)
  test_accuracy(labels, predictions)

# %% [markdown]
# ## función de entrenamiento  y prueba

# %%
def fitting(model,dataName,EPOCHS,N_batch,batch_size):
  for epoch in range(EPOCHS):
    
    for NB in range(N_batch):
      i=0
      with open(dataName+str(NB)+'.pickle','rb') as f:
                    train_x,train_y=pickle.load(f)
      while i+batch_size <= len(train_x):
        start = i
        end = i+batch_size
        batch_x = train_x[start:end]
        batch_y = train_y[start:end]
        train_step(model,batch_x,batch_y)
        i+=batch_size

    with open(dataName+'test.pickle','rb') as f:
                    test_x,test_y=pickle.load(f)
    test_step(model,test_x,test_y)
      
    template = 'Epoch {}, Perdida: {}, Exactitud: {}, Perdida de prueba: {}, Exactitud de prueba: {}'
    print(template.format(epoch+1,
                         train_loss.result(),
                        train_accuracy.result()*100,
                        test_loss.result(),
                        test_accuracy.result()*100))
    train_loss.reset_states()
    train_accuracy.reset_states()
    test_loss.reset_states()
    test_accuracy.reset_states()

# %%
fitting( Sentiment_model,'sentiment_set',EPOCHS=40,N_batch=2,batch_size=20)
# Out:
# Epoch 1, Perdida: 24276.404296875, Exactitud: 50.222225189208984, Perdida de prueba: 7400.0810546875, Exactitud de prueba: 49.599998474121094
# Epoch 2, Perdida: 10818.58203125, Exactitud: 50.411109924316406, Perdida de prueba: 3755.827392578125, Exactitud de prueba: 49.599998474121094
# Epoch 3, Perdida: 7374.4453125, Exactitud: 51.122222900390625, Perdida de prueba: 4054.718505859375, Exactitud de prueba: 49.599998474121094
# Epoch 4, Perdida: 2469.87060546875, Exactitud: 55.80000305175781, Perdida de prueba: 1315.370849609375, Exactitud de prueba: 59.29999923706055
# Epoch 5, Perdida: 1812.155517578125, Exactitud: 59.500003814697266, Perdida de prueba: 1201.27587890625, Exactitud de prueba: 60.79999923706055
# Epoch 6, Perdida: 1292.3223876953125, Exactitud: 60.68888854980469, Perdida de prueba: 669.8526000976562, Exactitud de prueba: 67.5999984741211
# Epoch 7, Perdida: 977.8981323242188, Exactitud: 63.58888626098633, Perdida de prueba: 413.57244873046875, Exactitud de prueba: 67.5999984741211
# Epoch 8, Perdida: 878.310791015625, Exactitud: 62.655555725097656, Perdida de prueba: 2616.08447265625, Exactitud de prueba: 51.0
# Epoch 9, Perdida: 677.34326171875, Exactitud: 63.44444274902344, Perdida de prueba: 1513.543701171875, Exactitud de prueba: 52.79999923706055
# Epoch 10, Perdida: 568.035888671875, Exactitud: 63.222225189208984, Perdida de prueba: 357.7563171386719, Exactitud de prueba: 63.099998474121094
# Epoch 11, Perdida: 326.7119445800781, Exactitud: 64.88888549804688, Perdida de prueba: 189.66036987304688, Exactitud de prueba: 68.5
# Epoch 12, Perdida: 249.5903778076172, Exactitud: 64.24444580078125, Perdida de prueba: 247.6922149658203, Exactitud de prueba: 63.099998474121094
# Epoch 13, Perdida: 206.0620880126953, Exactitud: 64.9111099243164, Perdida de prueba: 199.48544311523438, Exactitud de prueba: 62.5
# Epoch 14, Perdida: 132.6205596923828, Exactitud: 65.94444274902344, Perdida de prueba: 387.1466369628906, Exactitud de prueba: 52.89999771118164
# Epoch 15, Perdida: 241.17098999023438, Exactitud: 63.522220611572266, Perdida de prueba: 202.7890625, Exactitud de prueba: 60.60000228881836
# Epoch 16, Perdida: 124.57865142822266, Exactitud: 67.73333740234375, Perdida de prueba: 80.29782104492188, Exactitud de prueba: 67.79999542236328
# Epoch 17, Perdida: 71.70275115966797, Exactitud: 70.23332977294922, Perdida de prueba: 73.1455307006836, Exactitud de prueba: 66.79999542236328
# Epoch 18, Perdida: 46.22043991088867, Exactitud: 73.5888900756836, Perdida de prueba: 69.39286804199219, Exactitud de prueba: 66.29999542236328
# Epoch 19, Perdida: 42.21280288696289, Exactitud: 74.67778015136719, Perdida de prueba: 74.62468719482422, Exactitud de prueba: 65.5999984741211
# Epoch 20, Perdida: 25.826696395874023, Exactitud: 77.87777709960938, Perdida de prueba: 99.45316314697266, Exactitud de prueba: 64.30000305175781
# Epoch 21, Perdida: 15.981162071228027, Exactitud: 82.23333740234375, Perdida de prueba: 106.28555297851562, Exactitud de prueba: 62.0
# Epoch 22, Perdida: 6.995826721191406, Exactitud: 84.85556030273438, Perdida de prueba: 97.52364349365234, Exactitud de prueba: 62.19999694824219
# Epoch 23, Perdida: 1.850002408027649, Exactitud: 88.63333129882812, Perdida de prueba: 86.92765808105469, Exactitud de prueba: 62.599998474121094
# Epoch 24, Perdida: 1.02943754196167, Exactitud: 89.68888854980469, Perdida de prueba: 123.48690795898438, Exactitud de prueba: 60.39999771118164
# Epoch 25, Perdida: 0.3775883913040161, Exactitud: 91.13333129882812, Perdida de prueba: 83.6858139038086, Exactitud de prueba: 64.4000015258789
# Epoch 26, Perdida: 0.2871197760105133, Exactitud: 92.15555572509766, Perdida de prueba: 83.15435791015625, Exactitud de prueba: 64.4000015258789
# Epoch 27, Perdida: 0.21916785836219788, Exactitud: 92.53333282470703, Perdida de prueba: 82.81546020507812, Exactitud de prueba: 63.5
# Epoch 28, Perdida: 0.2187182754278183, Exactitud: 92.5777816772461, Perdida de prueba: 83.60691833496094, Exactitud de prueba: 64.0999984741211
# Epoch 29, Perdida: 11.204667091369629, Exactitud: 87.17778015136719, Perdida de prueba: 146.12042236328125, Exactitud de prueba: 62.19999694824219
# Epoch 30, Perdida: 6.245119571685791, Exactitud: 87.23333740234375, Perdida de prueba: 163.31658935546875, Exactitud de prueba: 63.400001525878906
# Epoch 31, Perdida: 11.066994667053223, Exactitud: 87.5777816772461, Perdida de prueba: 218.34068298339844, Exactitud de prueba: 61.79999542236328
# Epoch 32, Perdida: 5.202858924865723, Exactitud: 88.4000015258789, Perdida de prueba: 216.3570556640625, Exactitud de prueba: 63.5
# Epoch 33, Perdida: 4.800292015075684, Exactitud: 89.4222183227539, Perdida de prueba: 250.93606567382812, Exactitud de prueba: 64.5
# Epoch 34, Perdida: 1.0430113077163696, Exactitud: 91.06666564941406, Perdida de prueba: 247.47872924804688, Exactitud de prueba: 62.099998474121094
# Epoch 35, Perdida: 1.9039257764816284, Exactitud: 90.85556030273438, Perdida de prueba: 267.3514099121094, Exactitud de prueba: 64.0
# Epoch 36, Perdida: 3.0796592235565186, Exactitud: 90.46666717529297, Perdida de prueba: 308.6340637207031, Exactitud de prueba: 63.20000457763672
# Epoch 37, Perdida: 0.2997002601623535, Exactitud: 91.9888916015625, Perdida de prueba: 305.6982116699219, Exactitud de prueba: 63.599998474121094
# Epoch 38, Perdida: 5.002188682556152, Exactitud: 90.26667022705078, Perdida de prueba: 447.9080810546875, Exactitud de prueba: 62.30000305175781
# Epoch 39, Perdida: 8.736117362976074, Exactitud: 89.81111145019531, Perdida de prueba: 609.6932373046875, Exactitud de prueba: 61.5
# Epoch 40, Perdida: 0.8736762404441833, Exactitud: 91.33333587646484, Perdida de prueba: 522.35302734375, Exactitud de prueba: 61.19999694824219
